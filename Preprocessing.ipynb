# %%
#mount google drive

from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
! ls '/content/gdrive/MyDrive/humor_generation/datasets/'
# Out:
# glove.840B.300d.txt	    News_Category_Dataset_v2.json
# glove.840B.300d.zip.1	    news-headlines-humor.csv
# humorous_words_dataset.csv  news-headlines-humor.gsheet

# %% [markdown]
# ### Pipeline Structure:
#
# 1. **Preprocessing**: Identify "object" & "oblique nominal" nouns, as well as the verbs which they are associated with.
# 2. **Word Context Replacement**: Train a CBOW model to identify alternatives to the target object.
# 3. **Silly Synonyms**: Find "sillier" words to use, instead of the object and associated verb.
# 4. **Scoring**: After the word replacements, filter out the outputs that score low on grammaticality, and prefer those that have high "surprisal ratios".

# %%
# install stanza

# !pip install stanza
# Out:
# Collecting stanza
#   Downloading https://files.pythonhosted.org/packages/e7/8b/3a9e7a8d8cb14ad6afffc3983b7a7322a3a24d94ebc978a70746fcffc085/stanza-1.1.1-py3-none-any.whl (227kB)
#      |████████████████████████████████| 235kB 1.8MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from stanza) (4.41.1)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.6/dist-packages (from stanza) (3.12.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from stanza) (1.18.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from stanza) (2.23.0)
# Requirement already satisfied: torch>=1.3.0 in /usr/local/lib/python3.6/dist-packages (from stanza) (1.7.0+cu101)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf->stanza) (50.3.2)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.6/dist-packages (from protobuf->stanza) (1.15.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->stanza) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->stanza) (2020.11.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->stanza) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->stanza) (3.0.4)
# Requirement already satisfied: dataclasses in /usr/local/lib/python3.6/dist-packages (from torch>=1.3.0->stanza) (0.8)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.6/dist-packages (from torch>=1.3.0->stanza) (3.7.4.3)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch>=1.3.0->stanza) (0.16.0)
# Installing collected packages: stanza
# Successfully installed stanza-1.1.1

# %%
import stanza
stanza.download('en')
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/master/resources_1.1.0.json: 122kB [00:00, 19.5MB/s]
# 2020-12-06 23:39:38 INFO: Downloading default packages for language: en (English)...
# Downloading http://nlp.stanford.edu/software/stanza/1.1.0/en/default.zip: 100%|██████████| 428M/428M [06:32<00:00, 1.09MB/s]
# 2020-12-06 23:46:19 INFO: Finished downloading models and saved to /root/stanza_resources.

# %%
import stanza

nlp = stanza.Pipeline('en')
# Out:
# 2020-12-07 00:31:51 INFO: Loading these models for language: en (English):
# =========================
# | Processor | Package   |
# -------------------------
# | tokenize  | ewt       |
# | pos       | ewt       |
# | lemma     | ewt       |
# | depparse  | ewt       |
# | sentiment | sstplus   |
# | ner       | ontonotes |
# =========================
#
# 2020-12-07 00:31:51 INFO: Use device: cpu
# 2020-12-07 00:31:51 INFO: Loading: tokenize
# 2020-12-07 00:31:51 INFO: Loading: pos
# 2020-12-07 00:31:53 INFO: Loading: lemma
# 2020-12-07 00:31:53 INFO: Loading: depparse
# 2020-12-07 00:31:55 INFO: Loading: sentiment
# 2020-12-07 00:31:57 INFO: Loading: ner
# 2020-12-07 00:31:59 INFO: Done loading processors!

# %%
# first, open up the file and go through the sentences.
import stanza
import csv

nlp = stanza.Pipeline('en')

# once a proper target POS is found, parse it & save results.
# inputs:
#     wd: the word that has been tokenized & parsed out.
#     sent: the fully parsed sentence & all associated metadata.
def parse_tgt_pos(wd, sent, hdl_orig, id):
  hdl_final = hdl_orig
  tgt_text = wd.text
  tgt_loc = wd.misc

  # id the 'action' verb, if there is one.
  vb_text = ''
  vb_loc = ''
  head_ind = int(wd.head)-1
  head = sent.words[head_ind]
  if head.upos == 'VERB':
    vb_text = head.text
    vb_loc = head.misc

  # delete 'flat' noun modifiers.
  wd_id = int(wd.id)-1
  wd_id += 1
  del_start = 100000000000
  del_end = -1
  while wd_id <= len(sent.words)-1:
    wi = sent.words[wd_id]
    if wi.deprel == 'flat':
      print('[debug] deleting "flat" modifier', wi.text)
      s, e = wi.misc.split('|')
      sind = int(s.split('=')[1])
      eind = int(e.split('=')[1])
      del_start = min(del_start, sind)
      del_end = max(del_end, eind)
    else:
      break
    wd_id += 1
  
  ### NOTE: IF THE VERB COMES AFTER THE MODIFIER, THIS IS DANGEROUS...
  if del_end > -1:
    hdl_final = hdl_orig[:del_start] + hdl_orig[(del_end+1):]
    print("[debug] modified sentence: ", hdl_final)
  
  final_row = [id, hdl_final, tgt_text, tgt_loc, vb_text, vb_loc]
  return final_row


def parse_id_vb_tgt(input_path, output_path):
  with open(output_path, 'w') as fout:
    out_writer = csv.writer(fout)
    out_writer.writerow(['id', 'sentence', 'target text', 'target loc', 'verb text', 'verb loc'])  # header: [id, hdl_final, tgt_text, tgt_loc, vb_text, vb_loc]
    # open the input data file & process the data.
    with open(input_path) as f:
      news_reader = csv.reader(f)
      next(news_reader)  # skip the header
      #read through the content.
      ctr = 0
      for line in news_reader:
        ctr += 1
        id, hdl_orig, _ = line
        # first, disregard the special characters; do dep. parsing
        hdl_orig = hdl_orig.replace('<','').replace('/>', '')
        doc = nlp(hdl_orig)

        # next, identify the "object", identify "verb", delete "flat" wds
        for sent in doc.sentences:
          for wd in sent.words:
            # obj = object of verb, obl = verb modifier, nmod = noun modifier
            #   [note] taking 'nmod', it's very common & hit or miss...
            if wd.deprel in set(['obj', 'obl']):
              output_row = parse_tgt_pos(wd, sent, hdl_orig, id)
              if ctr <= 9:
                print(output_row)
                print('\n')
              # write output to file
              out_writer.writerow(output_row)


#--------------------------#
# actually run this function...
input_path = '/content/gdrive/MyDrive/humor_generation/datasets/news-headlines-humor.csv'
output_path = '/content/gdrive/MyDrive/humor_generation/datasets/news-headlines-humor-parsed.csv'

parse_id_vb_tgt(input_path, output_path)
# Out:
# 2020-12-07 02:43:30 INFO: Loading these models for language: en (English):
# =========================
# | Processor | Package   |
# -------------------------
# | tokenize  | ewt       |
# | pos       | ewt       |
# | lemma     | ewt       |
# | depparse  | ewt       |
# | sentiment | sstplus   |
# | ner       | ontonotes |
# =========================
#
# 2020-12-07 02:43:30 INFO: Use device: cpu
# 2020-12-07 02:43:30 INFO: Loading: tokenize
# 2020-12-07 02:43:30 INFO: Loading: pos
# 2020-12-07 02:43:31 INFO: Loading: lemma
# 2020-12-07 02:43:31 INFO: Loading: depparse
# 2020-12-07 02:43:33 INFO: Loading: sentiment
# 2020-12-07 02:43:34 INFO: Loading: ner
# 2020-12-07 02:43:35 INFO: Done loading processors!
# ['1723', 'Thousands of gay and bisexual men convicted of long-abolished sexual offences are posthumously pardoned', 'offences', 'start_char=69|end_char=77', 'convicted', 'start_char=34|end_char=43']
#
#
# [debug] deleting "flat" modifier Russia
# [debug] modified sentence:  Special prosecutor appointed to Trump
# ['12736', 'Special prosecutor appointed to Trump ', 'Trump', 'start_char=32|end_char=37', 'appointed', 'start_char=19|end_char=28']
#
#
# ['12274', 'Spanish police detain man and search Ripoll addresses in hunt for terror suspects ', 'man', 'start_char=22|end_char=25', 'detain', 'start_char=15|end_char=21']
#
#
# ['12274', 'Spanish police detain man and search Ripoll addresses in hunt for terror suspects ', 'hunt', 'start_char=57|end_char=61', 'addresses', 'start_char=44|end_char=53']
#
#
# ['12274', 'Spanish police detain man and search Ripoll addresses in hunt for terror suspects ', 'suspects', 'start_char=73|end_char=81', 'addresses', 'start_char=44|end_char=53']
#
#
# ['8823', "N.Y. Times reprimands reporter for sharing ' unfounded rumor ' about Melania Trump", 'reporter', 'start_char=22|end_char=30', 'reprimands', 'start_char=11|end_char=21']
#
#
# ['8823', "N.Y. Times reprimands reporter for sharing ' unfounded rumor ' about Melania Trump", 'rumor', 'start_char=55|end_char=60', 'sharing', 'start_char=35|end_char=42']
#
#
# [debug] deleting "flat" modifier Trump
# [debug] modified sentence:  N.Y. Times reprimands reporter for sharing ' unfounded rumor ' about Melania
# ['8823', "N.Y. Times reprimands reporter for sharing ' unfounded rumor ' about Melania ", 'Melania', 'start_char=69|end_char=76', 'sharing', 'start_char=35|end_char=42']
#
#
# ['5087', 'Vladimir Putin Releases Video Simulation Of Russian Missile striking Florida conveniently right on top of USSOCOM headquarters at MacDill AFB .', 'Florida', 'start_char=69|end_char=76', 'striking', 'start_char=60|end_char=68']
#
#
# ['5087', 'Vladimir Putin Releases Video Simulation Of Russian Missile striking Florida conveniently right on top of USSOCOM headquarters at MacDill AFB .', 'top', 'start_char=99|end_char=102', 'striking', 'start_char=60|end_char=68']
#
#
# ['13178', 'Ex-Goldman Sachs boss , Obama ambassador Murphy wins Democratic primary in bid to replace New Jersey GOP Gov. Christie', 'primary', 'start_char=64|end_char=71', 'wins', 'start_char=48|end_char=52']
#
#
# ['13178', 'Ex-Goldman Sachs boss , Obama ambassador Murphy wins Democratic primary in bid to replace New Jersey GOP Gov. Christie', 'bid', 'start_char=75|end_char=78', 'wins', 'start_char=48|end_char=52']
#
#
# ['13178', 'Ex-Goldman Sachs boss , Obama ambassador Murphy wins Democratic primary in bid to replace New Jersey GOP Gov. Christie', 'Christie', 'start_char=110|end_char=118', 'replace', 'start_char=82|end_char=89']
#
#
# ['11799', 'Trump ’s next military scapegoat : Foreign-born service members targeted by Pentagon', 'Pentagon', 'start_char=76|end_char=84', 'targeted', 'start_char=64|end_char=72']
#
#
# ['12497', 'US urges UN to punish Iran , but Russia says no sanctions', 'UN', 'start_char=9|end_char=11', 'urges', 'start_char=3|end_char=8']
#
#
# ['12497', 'US urges UN to punish Iran , but Russia says no sanctions', 'Iran', 'start_char=22|end_char=26', 'punish', 'start_char=15|end_char=21']
#
#
# ['12497', 'US urges UN to punish Iran , but Russia says no sanctions', 'sanctions', 'start_char=48|end_char=57', 'says', 'start_char=40|end_char=44']
#
#
# [debug] deleting "flat" modifier Moore
# [debug] modified sentence:  Newt Gingrich : Join Me in Supporting Judge Roy to Advance the President ’s Agenda
# [debug] deleting "flat" modifier Trump
# [debug] modified sentence:   Climate scientists exiled by Donald to reconvene at Columbia University and continue research
# [debug] deleting "flat" modifier Kushner
# [debug] modified sentence:  Trump 's personal attorneys are reportedly fed up with Jared
# [debug] deleting "flat" modifier Trump
# [debug] modified sentence:   Climate scientists exiled by Donald to reconvene at Columbia University and continue research
# [debug] deleting "flat" modifier Xi
# [debug] deleting "flat" modifier Jinping
# [debug] modified sentence:  In Beijing , Trump declines to hit President on trade : ‘ I do n’t blame China ’
# [debug] deleting "flat" modifier D'Souza
# [debug] modified sentence:  Trump to give ' full pardon ' to Dinesh
# [debug] deleting "flat" modifier Trump
# [debug] modified sentence:  Iran 's foreign minister mocks Donald ' putting him on notice '
# [debug] deleting "flat" modifier Moore
# [debug] modified sentence:  Fox &amp; Friends Spent Less Than 4 Minutes on Roy — But Hours on Weinstein
# [debug] deleting "flat" modifier Trump
# [debug] modified sentence:  Samantha Bee calls Ivanka a ' feckless c *** '
# [debug] deleting "flat" modifier Trump
# [debug] modified sentence:  The Australian refugee deal that has Donald so angry , explained
# [debug] deleting "flat" modifier Jinping
# [debug] modified sentence:  Trump , Aiming to Coax Xi , Bets on Flattery
# [debug] deleting "flat" modifier Sanders
# [debug] modified sentence:  The FBI probe you have n't heard about may come back to haunt Bernie
# [debug] deleting "flat" modifier Sanders
# [debug] modified sentence:  Indictment : Russia also helped Bernie , Jill Stein in election
# [debug] deleting "flat" modifier Trump
# [debug] modified sentence:  Comedian Samantha Bee used a vulgar insult to describe Ivanka – and now she 's apologizing
# [debug] deleting "flat" modifier Mueller
# [debug] modified sentence:  ' Witch hunt ' : Trump appears at odds with White House over Robert
# [debug] deleting "flat" modifier Bannon
# [debug] modified sentence:  Report : Ivanka Trump Helped Push Steve out of the White House
# [debug] deleting "flat" modifier Trump
# [debug] modified sentence:  Whos no longer supporting the unpresidential Donald now ?
# [debug] deleting "flat" modifier McCarthy
# [debug] modified sentence:  Sean Spicer jokes about Melissa impression of him during press briefing
# [debug] deleting "flat" modifier Xi
# [debug] deleting "flat" modifier Jinping
# [debug] modified sentence:  In Beijing , Trump declines to hit President on trade : ‘ I do n’t blame China ’
# [debug] deleting "flat" modifier Sanders
# [debug] modified sentence:  The FBI probe you have n't heard about may come back to haunt Bernie
# [debug] deleting "flat" modifier Clinton
# [debug] modified sentence:  Mike Pence Just Turned Over His Personal Emails , but Trump Is Still Focused on Hillary
# [debug] deleting "flat" modifier Pruitt
# [debug] modified sentence:  Trump 's EPA pick , Scott , has filed 14 lawsuits against the EPA
# [debug] deleting "flat" modifier Shulkin
# [debug] modified sentence:  2 Veterans groups urge Trump to keep VA Secretary David despite travel errors
# [debug] deleting "flat" modifier Johnson
# [debug] deleting "flat" modifier Sirleaf
# [debug] deleting "flat" modifier Steps
# [debug] modified sentence:  Liberians Vote For Next President , As Ellen Down
# [debug] deleting "flat" modifier Trump
# [debug] modified sentence:  Iran 's foreign minister mocks Donald ' putting him on notice '
# [debug] deleting "flat" modifier Kushner
# [debug] modified sentence:  Trump 's personal attorneys are reportedly fed up with Jared
# [debug] deleting "flat" modifier Flynn
# [debug] modified sentence:  Senior White House official refuses to say if Donald Trump supports Michael
# [debug] deleting "flat" modifier Clinton
# [debug] modified sentence:  Jeff Sessions Called For A Special Counsel After Loretta Lynch Met With Bill
# [debug] deleting "flat" modifier Johnson
# [debug] deleting "flat" modifier Sirleaf
# [debug] deleting "flat" modifier Steps
# [debug] modified sentence:  Liberians Vote For Next President , As Ellen Down
# [debug] deleting "flat" modifier Flynn
# [debug] modified sentence:  Senior White House official refuses to say if Donald Trump supports Michael
# [debug] deleting "flat" modifier Clinton
# [debug] modified sentence:  The Russian attorney at the heart of the scandal says Donald Trump Jr. " badly " wanted dirt on Hillary
# [debug] deleting "flat" modifier Tillerson
# [debug] modified sentence:  Trump humiliates Rex for the last time
# [debug] deleting "flat" modifier Trump
# [debug] modified sentence:  The Australian refugee deal that has Donald so angry , explained
# [debug] deleting "flat" modifier D'Souza
# [debug] modified sentence:  Trump to give ' full pardon ' to Dinesh
# [debug] deleting "flat" modifier Clinton
# [debug] modified sentence:  Donald Trump runs even with Hillary among 2016 voters in a hypothetical rematch , according latest WP/ABC poll .
# [debug] deleting "flat" modifier Russia
# [debug] modified sentence:  Special prosecutor appointed to Trump
# [debug] deleting "flat" modifier Trump
# [debug] modified sentence:  Comedian Samantha Bee used a vulgar insult to describe Ivanka – and now she 's apologizing
# [debug] deleting "flat" modifier Clinton
# [debug] modified sentence:  Jeff Sessions Called For A Special Counsel After Loretta Lynch Met With Bill
# [debug] deleting "flat" modifier Azar
# [debug] modified sentence:  Trump has nominated Alex for HHS Secretary
# [debug] deleting "flat" modifier Jinping
# [debug] modified sentence:  Trump , Aiming to Coax Xi , Bets on Flattery
# [debug] deleting "flat" modifier Tillerson
# [debug] modified sentence:  Trump humiliates Rex for the last time
# [debug] deleting "flat" modifier Trump
# [debug] modified sentence:  Frank Sinatra told Donald to “ go f *** himself ” , new book reveals
# [debug] deleting "flat" modifier Clinton
# [debug] modified sentence:  Mike Pence Just Turned Over His Personal Emails , but Trump Is Still Focused on Hillary
# [debug] deleting "flat" modifier dossier
# [debug] modified sentence:  Breaking down the Trump : What you need to know
# [debug] deleting "flat" modifier D'Souza
# [debug] modified sentence:   Trump to give ' full pardon ' to Dinesh
# [debug] deleting "flat" modifier Pruitt
# [debug] modified sentence:  Trump 's EPA pick , Scott , has filed 14 lawsuits against the EPA
# [debug] deleting "flat" modifier Sanders
# [debug] modified sentence:  Indictment : Russia also helped Bernie , Jill Stein in election
# [debug] deleting "flat" modifier Damore
# [debug] modified sentence:  The alt-right is furious Google fired James over his anti-diversity memo
# [debug] deleting "flat" modifier Trump
# [debug] modified sentence:  Whos no longer supporting the unpresidential Donald now ?
# [debug] deleting "flat" modifier Trump
# [debug] modified sentence:  Frank Sinatra told Donald to “ go f *** himself ” , new book reveals
# [debug] deleting "flat" modifier Bannon
# [debug] modified sentence:  Report : Ivanka Trump Helped Push Steve out of the White House
# [debug] deleting "flat" modifier Damore
# [debug] modified sentence:  The alt-right is furious Google fired James over his anti-diversity memo
# [debug] deleting "flat" modifier dossier
# [debug] modified sentence:  Breaking down the Trump : What you need to know
# [debug] deleting "flat" modifier Bundy
# [debug] modified sentence:  Judge Dismisses Federal Case Against Cliven And Sons , Bars Retrial : The Two-Way : NPR
# [debug] deleting "flat" modifier Clinton
# [debug] modified sentence:  Mike Pence Just Turned Over His Personal Emails , but Trump Is Still Focused on Hillary
# [debug] deleting "flat" modifier Flynn
# [debug] modified sentence:  Senior White House official refuses to say if Donald Trump supports Michael
# [debug] deleting "flat" modifier Trump
# [debug] modified sentence:  Comedian Samantha Bee used a vulgar insult to describe Ivanka – and now she 's apologizing
# [debug] deleting "flat" modifier May
# [debug] modified sentence:  Climate change : 84 % of Britons want Theresa to have a word with Donald Trump
# [debug] deleting "flat" modifier Jinping
# [debug] modified sentence:  Trump , Aiming to Coax Xi , Bets on Flattery
# [debug] deleting "flat" modifier Clinton
# [debug] modified sentence:  Jeff Sessions Called For A Special Counsel After Loretta Lynch Met With Bill
# [debug] deleting "flat" modifier Trump
# [debug] modified sentence:  Whos no longer supporting the unpresidential Donald now ?
# [debug] deleting "flat" modifier Clinton
# [debug] modified sentence:  The Russian attorney at the heart of the scandal says Donald Trump Jr. " badly " wanted dirt on Hillary
# [debug] deleting "flat" modifier Xi
# [debug] deleting "flat" modifier Jinping
# [debug] modified sentence:  In Beijing , Trump declines to hit President on trade : ‘ I do n’t blame China ’
# [debug] deleting "flat" modifier Johnson
# [debug] deleting "flat" modifier Sirleaf
# [debug] deleting "flat" modifier Steps
# [debug] modified sentence:  Liberians Vote For Next President , As Ellen Down
# [debug] deleting "flat" modifier dossier
# [debug] modified sentence:  Breaking down the Trump : What you need to know
# [debug] deleting "flat" modifier McCarthy
# [debug] modified sentence:  Sean Spicer jokes about Melissa impression of him during press briefing
# [debug] deleting "flat" modifier Tillerson
# [debug] modified sentence:  Trump humiliates Rex for the last time
# [debug] deleting "flat" modifier May
# [debug] modified sentence:  Climate change : 84 % of Britons want Theresa to have a word with Donald Trump
# [debug] deleting "flat" modifier Shulkin
# [debug] modified sentence:  2 Veterans groups urge Trump to keep VA Secretary David despite travel errors
# [debug] deleting "flat" modifier Azar
# [debug] modified sentence:   Trump has nominated Alex for HHS Secretary
# [debug] deleting "flat" modifier Moore
# [debug] modified sentence:  Fox &amp; Friends Spent Less Than 4 Minutes on Roy — But Hours on Weinstein
# [debug] deleting "flat" modifier Trump
# [debug] modified sentence:  Iran 's foreign minister mocks Donald ' putting him on notice '
# [debug] deleting "flat" modifier Clinton
# [debug] modified sentence:  Donald Trump runs even with Hillary among 2016 voters in a hypothetical rematch , according latest WP/ABC poll .
# [debug] deleting "flat" modifier Trump
# [debug] modified sentence:  The Australian refugee deal that has Donald so angry , explained
# [debug] deleting "flat" modifier Bannon
# [debug] modified sentence:  Report : Ivanka Trump Helped Push Steve out of the White House
# [debug] deleting "flat" modifier Bundy
# [debug] modified sentence:  Judge Dismisses Federal Case Against Cliven And Sons , Bars Retrial : The Two-Way : NPR
# [debug] deleting "flat" modifier Sanders
# [debug] modified sentence:  Indictment : Russia also helped Bernie , Jill Stein in election
# [debug] deleting "flat" modifier Trump
# [debug] modified sentence:  Climate scientists exiled by Donald to reconvene at Columbia University and continue research
# [debug] deleting "flat" modifier Pruitt
# [debug] modified sentence:  Trump 's EPA pick , Scott , has filed 14 lawsuits against the EPA
# [debug] deleting "flat" modifier Moore
# [debug] modified sentence:  Fox &amp; Friends Spent Less Than 4 Minutes on Roy — But Hours on Weinstein
# [debug] deleting "flat" modifier Trump
# [debug] modified sentence:  N.Y. Times reprimands reporter for sharing ' unfounded rumor ' about Melania
# [debug] deleting "flat" modifier Trump
# [debug] modified sentence:  Samantha Bee calls Ivanka a ' feckless c *** '
# [debug] deleting "flat" modifier Sanders
# [debug] modified sentence:  The FBI probe you have n't heard about may come back to haunt Bernie
# [debug] deleting "flat" modifier Mueller
# [debug] modified sentence:  ' Witch hunt ' : Trump appears at odds with White House over Robert
# [debug] deleting "flat" modifier Damore
# [debug] modified sentence:  The alt-right is furious Google fired James over his anti-diversity memo
# [debug] deleting "flat" modifier McCarthy
# [debug] modified sentence:  Sean Spicer jokes about Melissa impression of him during press briefing
# [debug] deleting "flat" modifier Trump
# [debug] modified sentence:  N.Y. Times reprimands reporter for sharing ' unfounded rumor ' about Melania
# [debug] deleting "flat" modifier Russia
# [debug] modified sentence:  Special prosecutor appointed to Trump
# [debug] deleting "flat" modifier Kushner
# [debug] modified sentence:  Trump 's personal attorneys are reportedly fed up with Jared
# [debug] deleting "flat" modifier Trump
# [debug] modified sentence:  Samantha Bee calls Ivanka a ' feckless c *** '
# [debug] deleting "flat" modifier May
# [debug] modified sentence:  Climate change : 84 % of Britons want Theresa to have a word with Donald Trump
# [debug] deleting "flat" modifier Clinton
# [debug] modified sentence:  The Russian attorney at the heart of the scandal says Donald Trump Jr. " badly " wanted dirt on Hillary
# [debug] deleting "flat" modifier Shulkin
# [debug] modified sentence:  2 Veterans groups urge Trump to keep VA Secretary David despite travel errors
# [debug] deleting "flat" modifier Bundy
# [debug] modified sentence:  Judge Dismisses Federal Case Against Cliven And Sons , Bars Retrial : The Two-Way : NPR
# [debug] deleting "flat" modifier Azar
# [debug] modified sentence:  Trump has nominated Alex for HHS Secretary
# [debug] deleting "flat" modifier Trump
# [debug] modified sentence:  Frank Sinatra told Donald to “ go f *** himself ” , new book reveals
# [debug] deleting "flat" modifier Moore
# [debug] modified sentence:  Newt Gingrich : Join Me in Supporting Judge Roy to Advance the President ’s Agenda
